# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_l/4hxt3fk515dfhkgkfl22djdm0000gn/T/ipykernel_2560/1495736958.py in <module>
#       3 URL = "https://www.ptt.cc/man/part-time/DF76/D780/DC4F/index.html"
#       4 #請求網站
# ----> 5 r = req.get(url)
#       6 #檢查回應。如果是200則成功請求
#       7 print(r)
#
# NameError: name 'url' is not defined

# %%
import yfinance as yf

# %%
df = yf.Ticker("2330.TW").history(period="max")
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2000-01-04 00:00:00+08:00   35.203030   35.203030   34.609725   35.203030
# 2000-01-05 00:00:00+08:00   35.203031   35.994041   34.807432   35.994041
# 2000-01-06 00:00:00+08:00   35.796335   35.994040   35.203030   35.203030
# 2000-01-07 00:00:00+08:00   34.016417   34.609722   33.620818   34.214123
# 2000-01-10 00:00:00+08:00   35.203032   35.598443   34.609727   35.400738
# ...                               ...         ...         ...         ...
# 2023-04-11 00:00:00+08:00  522.000000  527.000000  522.000000  524.000000
# 2023-04-12 00:00:00+08:00  523.000000  524.000000  517.000000  520.000000
# 2023-04-13 00:00:00+08:00  515.000000  517.000000  510.000000  510.000000
# 2023-04-14 00:00:00+08:00  516.000000  520.000000  513.000000  516.000000
# 2023-04-17 00:00:00+08:00  519.000000  519.000000  514.000000  516.000000
#
#                                  Volume  Dividends  Stock Splits
# Date
# ...
