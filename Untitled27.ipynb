# %%
import qrcode
from PIL import Image
import tkinter as tk
from tkinter import colorchooser, filedialog

def generate_qr_code(url, qr_color="black", bg_color="white"):
    # 生成QR Code圖像
    qr = qrcode.QRCode(version=1, box_size=10, border=4)
    qr.add_data(url)
    qr.make(fit=True)
    qr_img = qr.make_image(fill_color=qr_color, back_color=bg_color)
    return qr_img

def select_qr_color():
    # 開啟顏色選擇器選擇QR Code顏色
    _, qr_color = colorchooser.askcolor()
    qr_color_entry.delete(0, tk.END)
    qr_color_entry.insert(tk.END, qr_color)

def select_bg_color():
    # 開啟顏色選擇器選擇背景顏色
    _, bg_color = colorchooser.askcolor()
    bg_color_entry.delete(0, tk.END)
    bg_color_entry.insert(tk.END, bg_color)

def generate_qr():
    url = url_entry.get()
    qr_color = qr_color_entry.get()
    bg_color = bg_color_entry.get()

    qr_code = generate_qr_code(url, qr_color, bg_color)
    qr_code.save("qr_code5.png")  # 儲存QR Code圖像

    result_label.config(text="QR Code生成成功！")

# 建立主視窗
window = tk.Tk()
window.title("QR Code 生成器")

# 建立URL輸入框
url_label = tk.Label(window, text="網址:")
url_label.pack()
url_entry = tk.Entry(window)
url_entry.pack()

# 建立QR Code顏色選擇按鈕和輸入框
qr_color_button = tk.Button(window, text="選擇QR Code顏色", command=select_qr_color)
qr_color_button.pack()
qr_color_entry = tk.Entry(window)
qr_color_entry.pack()

# 建立背景顏色選擇按鈕和輸入框
bg_color_button = tk.Button(window, text="選擇背景顏色", command=select_bg_color)
bg_color_button.pack()
bg_color_entry = tk.Entry(window)
bg_color_entry.pack()

# 建立產生QR Code按鈕
generate_button = tk.Button(window, text="產生QR Code", command=generate_qr)
generate_button.pack()

# 建立結果顯示標籤
result_label = tk.Label(window, text="")
result_label.pack()

# 執行主迴圈
window.mainloop()

# %%
from PIL import Image
import tkinter as tk
from tkinter import filedialog, colorchooser

def generate_qr_code(url, qr_color="black", bg_color="white", icon_path=None):
    # 生成QR Code圖像
    qr = qrcode.QRCode(version=1, box_size=10, border=4)
    qr.add_data(url)
    qr.make(fit=True)
    qr_img = qr.make_image(fill_color=qr_color, back_color=bg_color)

    # 如果指定了圖標圖像，進行客製化處理
    if icon_path:
        icon = Image.open(icon_path)
        icon_size = (qr_img.size[0] // 4, qr_img.size[1] // 4)
        icon = icon.resize(icon_size)

        # 計算圖標在QR Code中的位置
        icon_position = ((qr_img.size[0] - icon_size[0]) // 2, (qr_img.size[1] - icon_size[1]) // 2)

        # 將圖標貼到QR Code圖像上
        qr_img.paste(icon, icon_position)

    return qr_img

def select_icon():
    # 讓使用者選擇圖標檔案路徑
    file_path = filedialog.askopenfilename(title="選擇圖標", filetypes=[("圖片文件", "*.jpg;*.png;*.jpeg")])
    icon_path.set(file_path)

def select_qr_color():
    # 讓使用者選擇QR Code的填充色
    color = colorchooser.askcolor(title="選擇QR Code顏色")[1]
    qr_color.set(color)

def select_bg_color():
    # 讓使用者選擇背景色
    color = colorchooser.askcolor(title="選擇背景顏色")[1]
    bg_color.set(color)

# 創建一個GUI窗口
root = tk.Tk()
root.title("QR Code 生成器")

# 創建一個變數用於存儲圖標路徑和QR Code的填充色和背景色
icon_path = tk.StringVar()
qr_color = tk.StringVar()
bg_color = tk.StringVar()

# 將填充色和背景色的初始值設為黑色和白色
qr_color.set("#000000")
bg_color.set("#FFFFFF")

# 創建幾個按鈕和標籤以及一個顯示QR Code的Canvas
tk.Label(root, text="輸入URL:").grid(row=0, column=0, padx=5, pady=5)
url_entry = tk.Entry(root)
url_entry.grid(row=0, column=1, padx=5, pady=5)

tk.Label(root, text="圖標:").grid(row=1, column=0, padx=5, pady=5)
icon_entry = tk.Entry(root, textvariable
.png") 
                      # 儲存QR Code圖像

    result_label.config(text="QR Code生成成功！")

# 建立主視窗
window = tk.Tk()
window.title("QR Code 生成器")

# 建立URL輸入框
url_label = tk.Label(window, text="網址:")
url_label.pack()
url_entry = tk.Entry(window)
url_entry.pack()

# 建立QR Code顏色選擇按鈕和輸入框
qr_color_button = tk.Button(window, text="選擇QR Code顏色", command=select_qr_color)
qr_color_button.pack()
qr_color_entry = tk.Entry(window)
qr_color_entry.pack()
                      
# 建立產生QR Code按鈕
generate_button = tk.Button(window, text="產生QR Code", command=generate_qr)
generate_button.pack()

# 建立結果顯示標籤
result_label = tk.Label(window, text="")
result_label.pack()

# 執行主迴圈
window.mainloop()
# Out:
#   File "/var/folders/_l/4hxt3fk515dfhkgkfl22djdm0000gn/T/ipykernel_6320/2328755741.py", line 61
#     .png")
#            ^
# SyntaxError: EOL while scanning string literal

# %%
import qrcode
from PIL import Image
import tkinter as tk
from tkinter import filedialog, colorchooser

def generate_qr_code(url, qr_color="black", bg_color="white", icon_path=None):
    # Generate the QR Code image
    qr = qrcode.QRCode(version=1, box_size=10, border=4)
    qr.add_data(url)
    qr.make(fit=True)
    qr_img = qr.make_image(fill_color=qr_color, back_color=bg_color)

    # If an icon image is specified, customize the QR Code image
    if icon_path:
        icon = Image.open(icon_path)
        icon_size = (qr_img.size[0] // 5, qr_img.size[1] // 5)
        icon = icon.resize(icon_size)

        # Calculate the position of the icon in the QR Code image
        icon_position = ((qr_img.size[0] - icon_size[0]) // 2, (qr_img.size[1] - icon_size[1]) // 2)

        # Paste the icon onto the QR Code image
        qr_img.paste(icon, icon_position)

    return qr_img

def select_icon():
    # Open the file dialog to select an icon image
    icon_path = filedialog.askopenfilename()
    icon_entry.delete(0, tk.END)
    icon_entry.insert(tk.END, icon_path)

def select_qr_color():
    # Open the color chooser to select the QR Code color
    _, qr_color = colorchooser.askcolor()
    qr_color_entry.delete(0, tk.END)
    qr_color_entry.insert(tk.END, qr_color)

def select_bg_color():
    # Open the color chooser to select the background color
    _, bg_color = colorchooser.askcolor()
    bg_color_entry.delete(0, tk.END)
    bg_color_entry.insert(tk.END, bg_color)

def generate_qr():
    url = url_entry.get()
    qr_color = qr_color_entry.get()
    bg_color = bg_color_entry.get()
    icon_path = icon_entry.get()

    qr_code = generate_qr_code(url, qr_color, bg_color, icon_path)
    qr_code.save("qr_code.png")  # Save the QR Code image

    result_label.config(text="QR Code generated successfully!")

# Create the main window
window = tk.Tk()
window.title("QR Code Generator")

# Create the URL input field
url_label = tk.Label(window, text="網址:")
url_label.pack()
url_entry = tk.Entry(window)
url_entry.pack()

# Create the QR Code color selection button and input field
qr_color_button = tk.Button(window, text="選擇QRcode顏色", command=select_qr_color)
qr_color_button.pack()
qr_color_entry = tk.Entry(window)
qr_color_entry.pack()

# Create the background color selection button and input field
bg_color_button = tk.Button(window, text="選擇背景顏色", command=select_bg_color)
bg_color_button.pack()
bg_color_entry = tk.Entry(window)
bg_color_entry.pack()

# Create the icon selection button and input field
icon_button = tk.Button(window, text='選擇圖片', command=select_icon)
icon_button.pack()
icon_entry = tk.Entry(window)
icon_entry.pack()

# Create the generate QR Code button
generate_button = tk.Button(window, text="生成QRcode", command=generate_qr)
generate_button.pack()

# Create the result label
result_label = tk.Label(window, text="")
result_label.pack

# 執行主迴圈
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/var/folders/_l/4hxt3fk515dfhkgkfl22djdm0000gn/T/ipykernel_1173/497503477.py", line 37, in select_qr_color
#     qr_color_entry.insert(tk.END, qr_color)
#   File "/opt/anaconda3/lib/python3.9/tkinter/__init__.py", line 3056, in insert
#     self.tk.call(self._w, 'insert', index, string)
# _tkinter.TclError: wrong # args: should be ".!entry2 insert index text"
# 2023-05-18 09:37:14.177 python[1173:18970] +[CATransaction synchronize] called within transaction
