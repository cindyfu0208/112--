# %%
import json
#將json檔匯入，存入dict中
test = open('good.json',encoding="utf8")
data = json.load(test)
type(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/_l/4hxt3fk515dfhkgkfl22djdm0000gn/T/ipykernel_6314/3589284752.py in <module>
#       2 #將json檔匯入，存入dict中
#       3 test = open('good.json',encoding="utf8")
# ----> 4 data = json.load(test)
#       5 type(data)
#
# /opt/anaconda3/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /opt/anaconda3/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# ...

# %%
#查看資料內容

data.items()
# Out:
# dict_items([('公墓設施概況', [{'RptNo': '3312-04-01-2', 'RptName': '臺中市公墓設施概況', 'StatCourseNo': '3029404a001', 'StatCourseName': '公墓設施概況-年底處數(單位:處)', 'DataDate': '2012/1/1 上午 12:00:00', 'PlaceNo': '010000066000010', 'PlaceName': '臺中市中區', 'PeriodNo': 'Y', 'PeriodName': '年', 'Complex1': '0200300001', 'ComplexName': '公立', 'Complex2': '0201200001', 'Complex2Name': '使用', 'Complex3': '0', 'Complex3Name': '', 'Complex4': '0', 'Complex4Name': '', 'Complex5': '0', 'Complex5Name': '', 'DeriveNo': '0', 'DeriveExplain': '', 'FValue': '0', 'SValue': '', 'RptDeptNo': '387020000A', 'RptDeptName': '民政局', 'CreateTime': '2015/8/25 下午 05:07:43', 'ModifyTime': '2019/5/30 上午 10:49:41'}, {'RptNo': '3312-04-01-2', 'RptName': '臺中市公墓設施概況', 'StatCourseNo': '3029404a001', 'StatCourseName': '公墓設施概況-年底處數(單位:處)', 'DataDate': '2012/1/1 上午 12:00:00', 'PlaceNo': '010000066000010', 'PlaceName': '臺中市中區', 'PeriodNo': 'Y', 'PeriodName': '年', 'Complex1': '0200300001', 'ComplexName': '公立', 'Complex2': '0201200002', 'Complex2Nam
# ...

# %%
temp
# Out:
# [{'RptNo': '3312-04-01-2',
#   'RptName': '臺中市公墓設施概況',
#   'StatCourseNo': '3029404a001',
#   'StatCourseName': '公墓設施概況-年底處數(單位:處)',
#   'DataDate': '2012/1/1 上午 12:00:00',
#   'PlaceNo': '010000066000010',
#   'PlaceName': '臺中市中區',
#   'PeriodNo': 'Y',
#   'PeriodName': '年',
#   'Complex1': '0200300001',
#   'ComplexName': '公立',
#   'Complex2': '0201200001',
#   'Complex2Name': '使用',
#   'Complex3': '0',
#   'Complex3Name': '',
#   'Complex4': '0',
#   'Complex4Name': '',
#   'Complex5': '0',
#   'Complex5Name': '',
#   'DeriveNo': '0',
#   'DeriveExplain': '',
#   'FValue': '0',
#   'SValue': '',
#   'RptDeptNo': '387020000A',
#   'RptDeptName': '民政局',
#   'CreateTime': '2015/8/25 下午 05:07:43',
#   'ModifyTime': '2019/5/30 上午 10:49:41'},
#  {'RptNo': '3312-04-01-2',
#   'RptName': '臺中市公墓設施概況',
#   'StatCourseNo': '3029404a001',
#   'StatCourseName': '公墓設施概況-年底處數(單位:處)',
#   'DataDate': '2012/1/1 上午 12:00:00',
#   'PlaceNo': '010000066000010',
#   'PlaceName': '臺中市中區',
# ...
