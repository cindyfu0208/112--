# %%
#取得原始碼
from bs4 import BeautifulSoup as bs
import requests

url="https://www.ptt.cc/bbs/basketballTW/index.html"#網頁網址從此放入
headers={
    
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"

}

res = requests.get(url,headers = headers)

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 basketballTW 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/basketballTW/index.html"><span class="board-label">看板 </span>basketballTW</a>
# ...

# %%
#第一篇
data=soup.select("div.r-ent")
print(data[0])
# Out:
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
# <a href="/bbs/basketballTW/M.1681693212.A.283.html">Re: [新聞] 曝姚明或成立新聯賽！發展東亞籃球</a>
# </div>
# <div class="meta">
# <div class="author">johnbill</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/basketballTW/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E6%9B%9D%E5%A7%9A%E6%98%8E%E6%88%96%E6%88%90%E7%AB%8B%E6%96%B0%E8%81%AF%E8%B3%BD%EF%BC%81%E7%99%BC%E5%B1%95%E6%9D%B1%E4%BA%9E%E7%B1%83%E7%90%83">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/basketballTW/search?q=author%3Ajohnbill">搜尋看板內 johnbill 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/17</div>
# <div class="mark"></div>
# </div>
# </div>

# %%
#STRIP去頭尾＃出標題
for ele in data:
    titles=ele.select("div.title")[0].text.strip()
    print("標題:",titles)
# Out:
# 標題: Re: [新聞] 曝姚明或成立新聯賽！發展東亞籃球
# 標題: [新聞] 麥卡洛強調自己不髒 出拳因丁恩迪吐口水
# 標題: [乳摸] 雲豹DD不想續約?
# 標題: [公告] 台籃板板規 2.0
# 標題: [公告] 票務區
# 標題: [情報] 2022-23 PLG/T1/SBL/WSBL 賽程表

# %%
for ele in data:
    title = ele.select("div.title")[0].text.strip()
    
    print("標題:",title)
    time=ele.select("div.date")[0].text
    print("時間:",time)
    writter=ele.select("div.author")[0].text
    print("作者:",writter)
# Out:
# 標題: Re: [新聞] 曝姚明或成立新聯賽！發展東亞籃球
# 時間:  4/17
# 作者: johnbill
# 標題: [新聞] 麥卡洛強調自己不髒 出拳因丁恩迪吐口水
# 時間:  4/17
# 作者: kenny1300175
# 標題: [乳摸] 雲豹DD不想續約?
# 時間:  4/17
# 作者: leptoneta
# 標題: [公告] 台籃板板規 2.0
# 時間:  2/04
# 作者: NanashiMumei
# 標題: [公告] 票務區
# 時間:  3/19
# 作者: NanashiMumei
# 標題: [情報] 2022-23 PLG/T1/SBL/WSBL 賽程表
# 時間: 10/04
# 作者: nepholi

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_l/4hxt3fk515dfhkgkfl22djdm0000gn/T/ipykernel_1449/2132702956.py in <module>
#       1 import bs4
# ----> 2 root=bs4.BeautifulSoup(data, "html.parser")
#       3 titles=root.find_all("div", class_="title")
#       4 for title in titles:
#       5     if title.a !=None:
#
# /opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     324         rejections = []
#     325         success = False
# --> 326         for (self.markup, self.original_encoding, self.declared_html_encoding,
#     327          self.contains_replacement_characters) in (
#     328              self.builder.prepare_markup(
#
# ...
